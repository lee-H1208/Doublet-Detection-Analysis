# %% [markdown]
# ## Doublet Removal - Pseudo Doublets

# %%
import scanpy as sc
import numpy as np
import pandas as pd
from matplotlib import rcParams
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy
import os

sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')

# data files are in the filtered matrix folder from CellRanger which has been renamed to the sample name
sample_name = r'sc85_3g' #r'sc70_1' #r'sc72_1'
data_path = r"../raw_data/"
data_files_path = data_path + sample_name + r""

results_path = 'results/'
results_file = results_path + sample_name + '-db.h5ad'  # the file that will store the analysis results
metrics_file = results_path + sample_name + '_db_metrics.csv'  # the file that will store the metrics
# make results folder if it doesn't exist
if not os.path.exists(results_path):
    os.makedirs(results_path, exist_ok=False)
# Out:
# C:\Users\leeh1\McKinnonRosatiLab\jl\lib\site-packages\anndata\utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\leeh1\McKinnonRosatiLab\jl\lib\site-packages\anndata\utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\leeh1\McKinnonRosatiLab\jl\lib\site-packages\anndata\utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\leeh1\McKinnonRosatiLab\jl\lib\site-packages\anndata\utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\leeh1\McKinnonRosatiLab\jl\lib\site-packages\anndata\utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\leeh1\McKinnonRosatiLab\jl\lib\site-packages\anndata\utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\leeh1\McKinnonRosatiLab\jl\lib\site-packages\anndata\utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# scanpy==1.10.3 anndata==0.11.0 umap==0.5.7 numpy==1.26.4 scipy==1.14.1 pandas==2.2.3 scikit-learn==1.5.2 statsmodels==0.14.4 igraph==0.11.8 louvain==0.8.2 pynndescent==0.5.13

# %% [markdown]
# #### Setup R environment

# %%
import os
os.environ['R_HOME'] = r"C:\Program Files\R\R-4.4.2"  
import anndata2ri # order matters, comes after defining 'R_HOME
import logging
import rpy2.rinterface_lib.callbacks as rcb
import rpy2.robjects as ro
rcb.logger.setLevel(logging.ERROR)
ro.pandas2ri.activate()
anndata2ri.activate()

# %reload_ext rpy2.ipython
# Out:
# C:\Users\leeh1\AppData\Local\Temp\ipykernel_12516\364680306.py:9: DeprecationWarning: The global conversion available with activate() is deprecated and will be removed in the next major release. Use a local converter.
#   anndata2ri.activate()
# C:\Users\leeh1\McKinnonRosatiLab\jl\lib\site-packages\rpy2\robjects\packages.py:367: UserWarning: The symbol 'quartz' is not in this R namespace/package.
#   warnings.warn(

# %%
# %%R
# .libPaths(c("C:/Users/leeh1/AppData/Local/R/win-library/4.4", .libPaths()))
# library(Seurat)
# library(scater)
# library(scDblFinder)
# library(BiocParallel)
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching package: 'SeuratObject'
#
# The following objects are masked from 'package:base':
#
#     intersect, t
#
# Loading required package: SingleCellExperiment
# Loading required package: SummarizedExperiment
# Loading required package: MatrixGenerics
# Loading required package: matrixStats
#
# Attaching package: 'MatrixGenerics'
#
# The following objects are masked from 'package:matrixStats':
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Loading required package: GenomicRanges
# Loading required package: stats4
# Loading required package: BiocGenerics
#
# Attaching package: 'BiocGenerics'
#
# The following object is masked from 'package:SeuratObject':
#
#     intersect
#
# The following objects are masked from 'package:stats':
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from 'package:base':
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, saveRDS, setdiff,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
# Loading required package: S4Vectors
#
# Attaching package: 'S4Vectors'
#
# The following object is masked from 'package:utils':
#
#     findMatches
#
# The following objects are masked from 'package:base':
#
#     expand.grid, I, unname
#
# Loading required package: IRanges
#
# Attaching package: 'IRanges'
#
# The following object is masked from 'package:sp':
#
#     %over%
#
# The following object is masked from 'package:grDevices':
#
#     windows
#
# Loading required package: GenomeInfoDb
# Loading required package: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: 'Biobase'
#
# The following object is masked from 'package:MatrixGenerics':
#
#     rowMedians
#
# The following objects are masked from 'package:matrixStats':
#
#     anyMissing, rowMedians
#
#
# Attaching package: 'SummarizedExperiment'
#
# The following object is masked from 'package:Seurat':
#
#     Assays
#
# The following object is masked from 'package:SeuratObject':
#
#     Assays
#
# Loading required package: scuttle
# Loading required package: ggplot2

# %% [markdown]
# #### Load data

# %% [markdown]
# Read in count data into an [`AnnData`](https://anndata.readthedocs.io/en/latest/anndata.AnnData.html) object.
# The matrix.mtx file contains a sparse matrix of the counts.
# Barcodes file contains the sample names in the format: AAACCCAAGACCATAA-1
# Features file contains the gene id in the format: ENSMUSG00000051951, Xkr4, Gene Expression
#
# The number of counts per cell will be relatively low since only UMIs are counted by Cellranger

# %%
adata = sc.read_10x_mtx(
    data_files_path,              # the directory with the `.mtx` file
    var_names='gene_symbols',     # use gene symbols for the variable names (variables-axis index)
    cache=True)                   # write a cache file for faster subsequent reading

# adata.var_names_make_unique()  # this is unnecessary if using `var_names='gene_ids'` in `sc.read_10x_mtx`
print('Data matrix is sparse:', scipy.sparse.issparse(adata.X))
print()

# make the obs names unique by adding the sample name
adata.obs_names = [g.split("-")[0] + '_' + sample_name for g in adata.obs_names]
print(adata.obs_names[0:2])
print()
print('Number of cells =', f"{adata.n_obs:,.0f}")
print('Number of genes =', f"{adata.n_vars:,.0f}")
print('Number of counts =', f"{adata.X.sum():,.0f}")
print('Mean counts per cell =', f"{adata.X.sum()/adata.n_obs:,.0f}")
adata
# Out:
# ... writing an h5ad cache file to speedup reading next time
# Data matrix is sparse: True
#
# Index(['AAACAGCCAACATAAG_sc85_3g', 'AAACAGCCAATGAAGC_sc85_3g'], dtype='object')
#
# Number of cells = 13,572
# Number of genes = 36,530
# Number of counts = 18,226,496
# Mean counts per cell = 1,343
# AnnData object with n_obs × n_vars = 13572 × 36530
#     var: 'gene_ids', 'feature_types'

# %%
n_cells = adata.n_obs
n_genes = adata.n_vars
n_counts = adata.X.sum()    
counts_per_cell = round(n_counts / n_cells)

df_metrics = pd.DataFrame([n_cells, n_genes, n_counts, counts_per_cell], \
                  index = ['Number of cells', 'Number of genes', 'Number of counts','Mean counts per cell']).T
df_metrics.iloc[:, 1:] = df_metrics.iloc[:,1:].applymap('{:,.0f}'.format)
df_metrics.index = [sample_name]
df_metrics
# Out:
# C:\Users\leeh1\AppData\Local\Temp\ipykernel_12516\1815972615.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_metrics.iloc[:, 1:] = df_metrics.iloc[:,1:].applymap('{:,.0f}'.format)
# C:\Users\leeh1\AppData\Local\Temp\ipykernel_12516\1815972615.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0    36,530
# Name: Number of genes, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_metrics.iloc[:, 1:] = df_metrics.iloc[:,1:].applymap('{:,.0f}'.format)
# C:\Users\leeh1\AppData\Local\Temp\ipykernel_12516\1815972615.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0    18,226,496
# Name: Number of counts, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_metrics.iloc[:, 1:] = df_metrics.iloc[:,1:].applymap('{:,.0f}'.format)
# C:\Users\leeh1\AppData\Local\Temp\ipykernel_12516\1815972615.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0    1,343
# Name: Mean counts per cell, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_metrics.iloc[:, 1:] = df_metrics.iloc[:,1:].applymap('{:,.0f}'.format)
#          Number of cells Number of genes Number of counts Mean counts per cell
# sc85_3g          13572.0          36,530       18,226,496                1,343

# %% [markdown]
# ### Detect doublets
# Remove "empty" genes before doublet detection.

# %%
sc.pp.filter_genes(adata, min_cells=1)
df_metrics['Filter genes:'] = ' '
df_metrics['Number of genes removed'] = n_genes - adata.n_vars
# Out:
# filtered out 11005 genes that are detected in less than 1 cells

# %%
data_mat = adata.X.T                 # transform data matrix
doublet_ratio = n_cells/1000*0.008   # calculate multiplet rate based on 10x formula
print('multiplet rate = %4.1f' %(doublet_ratio*100), '%')
# Out:
# multiplet rate = 10.9 %

# %%
# %%R -i data_mat -i doublet_ratio -o doublet_score -o doublet_class
#
# set.seed(123)
# sce = scDblFinder(SingleCellExperiment(list(counts=data_mat),), dbr=doublet_ratio)
# doublet_score = sce$scDblFinder.score
# doublet_class = sce$scDblFinder.class
# Out:
# Creating ~10858 artificial doublets...
# Dimensional reduction
# Evaluating kNN...
# Training model...
# iter=0, 2148 cells excluded from training.
# iter=1, 2031 cells excluded from training.
# iter=2, 1944 cells excluded from training.
# Threshold found:0.492
# 1778 (13.1%) doublets called

# %%
doublets = [1.0 if x == 'doublet' else 0 for x in doublet_class]
adata.obs["scDblFinder_score"] = doublet_score
adata.obs["scDblFinder_class"] = doublet_class
adata.obs["doublet"] = doublets

# %%
doublet_percentage = sum(doublets)/adata.n_obs*100
print('Doublet percentage = %4.1f' %(doublet_percentage))
df_metrics['Doublet removal:'] = ' '
df_metrics['Doublet percentage'] =  doublet_percentage

adata.obs.scDblFinder_class.value_counts()
# Out:
# Doublet percentage = 13.1
# scDblFinder_class
# singlet    11794
# doublet     1778
# Name: count, dtype: int64

# %%
sc.pp.calculate_qc_metrics(adata, percent_top=None, log1p=False, inplace=True)
sc.pl.violin(adata, 'n_genes_by_counts',jitter=0.4, groupby = 'scDblFinder_class')

# %%
num_before = adata.n_obs
singlets = adata.obs["scDblFinder_class"] == 'singlet'
num_after = adata[singlets].n_obs
n_genes = adata[singlets].n_vars
n_counts = adata[singlets].X.sum()    
counts_per_cell = round(n_counts / n_cells)

print('Number of cells before doublet removal =', num_before)
print('Number of cells after doublet removal =', num_after)
print('Number of cells removed =', num_before - num_after)
removed_percentage = (num_before - num_after)/num_before*100
print('Percentage of cells removed = %4.1f' %(removed_percentage))
n_counts = adata.X.sum()  
print('Number of counts =', f"{n_counts:,.0f}")
print('Mean counts per cell =', f"{counts_per_cell:,.0f}")

df_metrics['Number of cells removed'] =  num_before - num_after
df_metrics['After doublet removal:'] = ' '
df_metrics['Number of cells -db'] = num_after
df_metrics['Number of genes -db'] = n_genes
df_metrics['Number of counts -db'] = n_counts
df_metrics['Mean counts per cell -db'] = counts_per_cell
# Out:
# Number of cells before doublet removal = 13572
# Number of cells after doublet removal = 11794
# Number of cells removed = 1778
# Percentage of cells removed = 13.1
# Number of counts = 18,226,496
# Mean counts per cell = 1,018

# %% [markdown]
# ### Isolating Singlets

# %%
bdata = adata[singlets].copy()
print(bdata)
# Out:
# AnnData object with n_obs × n_vars = 11794 × 25525
#     obs: 'scDblFinder_score', 'scDblFinder_class', 'doublet', 'n_genes_by_counts', 'total_counts'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'scDblFinder_class_colors'

# %% [markdown]
# ### UMAP
# Visualize the data before and after doublet removal.

# %%
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata)
sc.tl.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
# Out:
# normalizing counts per cell
#     finished (0:00:00)
# extracting highly variable genes
#     finished (0:00:00)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)
# computing PCA
#     with n_comps=50
#     finished (0:00:01)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:55)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm)
#     'umap', UMAP parameters (adata.uns) (0:00:13)

# %%
rcParams['figure.figsize'] = 6, 5.5
sc.pl.umap(adata, color=['doublet'])

# %%
sc.pl.scatter(adata, 'total_counts', 'n_genes_by_counts', color='doublet')

# %% [markdown]
# #### Cleaning up `bdata`

# %%
print(bdata.shape)
print(bdata.obs)
print(bdata.var_names)
# Out:
# (11794, 25525)
#                           scDblFinder_score scDblFinder_class  doublet  \
# AAACAGCCAACATAAG_sc85_3g           0.000237           singlet      0.0
# AAACAGCCAATGAAGC_sc85_3g           0.000021           singlet      0.0
# AAACAGCCAATTAAGG_sc85_3g           0.025220           singlet      0.0
# AAACAGCCACGTGCTG_sc85_3g           0.067677           singlet      0.0
# AAACAGCCACTGACCG_sc85_3g           0.036047           singlet      0.0
# ...                                     ...               ...      ...
# TTTGTGTTCGTTACTT_sc85_3g           0.000314           singlet      0.0
# TTTGTGTTCTGTTCAT_sc85_3g           0.000162           singlet      0.0
# TTTGTTGGTCCTTAGT_sc85_3g           0.000297           singlet      0.0
# TTTGTTGGTGTCCAGG_sc85_3g           0.000040           singlet      0.0
# TTTGTTGGTTGTCATC_sc85_3g           0.000268           singlet      0.0
#
#                           n_genes_by_counts  total_counts
# AAACAGCCAACATAAG_sc85_3g                654         832.0
# AAACAGCCAATGAAGC_sc85_3g                867        1017.0
# AAACAGCCAATTAAGG_sc85_3g               1804        3961.0
# AAACAGCCACGTGCTG_sc85_3g                855        1120.0
# AAACAGCCACTGACCG_sc85_3g                739        1249.0
# ...                                     ...           ...
# TTTGTGTTCGTTACTT_sc85_3g               1169        1381.0
# TTTGTGTTCTGTTCAT_sc85_3g                842        1090.0
# TTTGTTGGTCCTTAGT_sc85_3g                451        1429.0
# TTTGTTGGTGTCCAGG_sc85_3g                107         528.0
# TTTGTTGGTTGTCATC_sc85_3g                849        1052.0
#
# [11794 rows x 5 columns]
# Index(['LOC139071432', 'LOC107385520', 'LOC139072245', 'LOC139064302',
#        'LOC139072279', 'LOC129159217', 'LOC139071444', 'LOC129160091',
#        'LOC107372990', 'LOC107374007',
#        ...
#        'KEG92_t17', 'KEG92_t18', 'KEG92_t19', 'KEG92_p03', 'KEG92_p02',
#        'KEG92_t20', 'KEG92_p01', 'KEG92_t21', 'KEG92_t22', 'KEG92_t23'],
#       dtype='object', length=25525)

# %%
bdata.obs.drop(columns=["scDblFinder_score"], inplace=True)
bdata.obs.drop(columns=["scDblFinder_class"], inplace=True)
bdata.obs.drop(columns=["n_genes_by_counts"], inplace=True)
bdata.obs.drop(columns=["total_counts"], inplace=True)
bdata.obs.drop(columns=["doublet"], inplace=True)

print(bdata.obs)
# Out:
# Empty DataFrame
# Columns: []
# Index: [AAACAGCCAACATAAG_sc85_3g, AAACAGCCAATGAAGC_sc85_3g, AAACAGCCAATTAAGG_sc85_3g, AAACAGCCACGTGCTG_sc85_3g, AAACAGCCACTGACCG_sc85_3g, AAACAGCCATTAGGTT_sc85_3g, AAACATGCAAACCTAT_sc85_3g, AAACATGCAACAGGAT_sc85_3g, AAACATGCACTAAGTT_sc85_3g, AAACATGCAGCTCAAC_sc85_3g, AAACATGCATGAGCAG_sc85_3g, AAACATGCATTAAGCT_sc85_3g, AAACCAACAACTAGAA_sc85_3g, AAACCAACAATACTGT_sc85_3g, AAACCAACAATTGAGA_sc85_3g, AAACCGAAGCCAAATC_sc85_3g, AAACCGAAGCGGTTAT_sc85_3g, AAACCGCGTAAGGTCC_sc85_3g, AAACCGCGTGAGCAAG_sc85_3g, AAACCGCGTGTAATAC_sc85_3g, AAACCGCGTTAGGTTG_sc85_3g, AAACCGCGTTATCCTA_sc85_3g, AAACCGCGTTCGCTTG_sc85_3g, AAACCGCGTTGTAAAC_sc85_3g, AAACCGGCAACTAACT_sc85_3g, AAACCGGCACCTAATG_sc85_3g, AAACCGGCATGGCCCA_sc85_3g, AAACCGGCATTAAAGG_sc85_3g, AAACGCGCAAGGCCAA_sc85_3g, AAACGCGCACCTCGCT_sc85_3g, AAACGCGCACGTAAGG_sc85_3g, AAACGCGCAGGTCCTG_sc85_3g, AAACGCGCAGGTTCAC_sc85_3g, AAACGCGCAGTAAAGC_sc85_3g, AAACGCGCATTAAAGG_sc85_3g, AAACGCGCATTGTGGC_sc85_3g, AAACGGATCATGTTTC_sc85_3g, AAACGGATCATTAGCA_sc85_3g, AAACGGATCATTTAGG_sc85_3g, AAACGGATCCGTCCAT_sc85_3g, AAACGGATCCTGAATA_sc85_3g, AAACGGATCGCGACAC_sc85_3g, AAACGGATCGTAATCA_sc85_3g, AAACGGATCTGTAATG_sc85_3g, AAACGGATCTTGCAAA_sc85_3g, AAACGTACAAAGCTCC_sc85_3g, AAACGTACACGTAAGG_sc85_3g, AAACGTACACTGACTA_sc85_3g, AAACGTACAGCAACAG_sc85_3g, AAACGTACAGCATTAT_sc85_3g, AAACGTACATAATGAG_sc85_3g, AAAGCAAGTATTCGCT_sc85_3g, AAAGCAAGTCAACAAT_sc85_3g, AAAGCAAGTTAGGCGT_sc85_3g, AAAGCAAGTTGTCATC_sc85_3g, AAAGCAAGTTTCCTCC_sc85_3g, AAAGCACCACCTACTT_sc85_3g, AAAGCACCAGTGAACG_sc85_3g, AAAGCACCATTGCGAC_sc85_3g, AAAGCCCGTAAATTGC_sc85_3g, AAAGCCCGTAACCAGC_sc85_3g, AAAGCCCGTACAATGT_sc85_3g, AAAGCCCGTAGCTAGC_sc85_3g, AAAGCCCGTATTGGTG_sc85_3g, AAAGCCCGTCACGAAC_sc85_3g, AAAGCCCGTTGTTGTC_sc85_3g, AAAGCCCGTTTGTCTA_sc85_3g, AAAGCCGCAATAAGCA_sc85_3g, AAAGCCGCAGCGCTTG_sc85_3g, AAAGCCGCAGGATGGC_sc85_3g, AAAGCCGCAGTTTGGC_sc85_3g, AAAGCGGGTGTCCTGC_sc85_3g, AAAGCGGGTGTGCACG_sc85_3g, AAAGCGGGTTCCATTA_sc85_3g, AAAGCGGGTTTGGGTA_sc85_3g, AAAGCTTGTAACGAGG_sc85_3g, AAAGCTTGTACCGTAA_sc85_3g, AAAGCTTGTAGTTGGC_sc85_3g, AAAGCTTGTATTACCC_sc85_3g, AAAGCTTGTTACATCC_sc85_3g, AAAGCTTGTTAGGACC_sc85_3g, AAAGCTTGTTATAGCG_sc85_3g, AAAGCTTGTTGTCCAT_sc85_3g, AAAGGACGTAATCGGC_sc85_3g, AAAGGACGTATTGCAG_sc85_3g, AAAGGACGTCAAAGGG_sc85_3g, AAAGGACGTTAAGGTT_sc85_3g, AAAGGACGTTTGCAGA_sc85_3g, AAAGGAGCAATAACGA_sc85_3g, AAAGGAGCAGCATGAG_sc85_3g, AAAGGAGCAGCCAGTT_sc85_3g, AAAGGAGCATAGCTGC_sc85_3g, AAAGGAGCATGTTTGG_sc85_3g, AAAGGAGCATTGTGAT_sc85_3g, AAAGGTTAGAACAAGT_sc85_3g, AAAGGTTAGAGCCGCT_sc85_3g, AAAGGTTAGGACTAAG_sc85_3g, AAAGGTTAGGCGCATC_sc85_3g, AAAGGTTAGGGACTAA_sc85_3g, AAAGGTTAGGGTGGAT_sc85_3g, ...]
#
# [11794 rows x 0 columns]

# %%
print(bdata.X)
# Out:
# <Compressed Sparse Column sparse matrix of dtype 'float32'
# 	with 9799276 stored elements and shape (11794, 25525)>
#   Coords	Values
#   (87, 0)	1.0
#   (4569, 0)	1.0
#   (5634, 0)	1.0
#   (5832, 0)	1.0
#   (6621, 0)	1.0
#   (8580, 0)	1.0
#   (8782, 0)	1.0
#   (749, 1)	1.0
#   (4067, 1)	1.0
#   (4271, 1)	1.0
#   (5416, 1)	1.0
#   (6944, 1)	1.0
#   (4065, 2)	1.0
#   (5399, 2)	1.0
#   (5653, 2)	1.0
#   (6692, 2)	1.0
#   (759, 3)	1.0
#   (6, 4)	1.0
#   (31, 4)	1.0
#   (45, 4)	1.0
#   (1420, 4)	1.0
#   (1493, 4)	1.0
#   (1721, 4)	1.0
#   (1849, 4)	1.0
#   (2254, 4)	1.0
#   :	:
#   (7994, 25524)	1.0
#   (8236, 25524)	1.0
#   (8420, 25524)	1.0
#   (8442, 25524)	1.0
#   (8557, 25524)	1.0
#   (8633, 25524)	1.0
#   (8826, 25524)	1.0
#   (8935, 25524)	2.0
#   (8941, 25524)	1.0
#   (9181, 25524)	1.0
#   (9370, 25524)	1.0
#   (9451, 25524)	1.0
#   (9535, 25524)	1.0
#   (9600, 25524)	1.0
#   (9643, 25524)	1.0
#   (9706, 25524)	1.0
#   (9889, 25524)	1.0
#   (10233, 25524)	1.0
#   (10288, 25524)	1.0
#   (10320, 25524)	1.0
#   (10735, 25524)	1.0
#   (10823, 25524)	1.0
#   (10834, 25524)	1.0
#   (11563, 25524)	1.0
#   (11772, 25524)	1.0

# %% [markdown]
# ### Rerun scDblFinder

# %%
print('Data matrix is sparse:', scipy.sparse.issparse(bdata.X))
print()

# make the obs names unique by adding the sample name
bdata.obs_names = [g.split("-")[0] + '_' + sample_name for g in bdata.obs_names]
print(bdata.obs_names[0:2])
print()
print('Number of cells =', f"{bdata.n_obs:,.0f}")
print('Number of genes =', f"{bdata.n_vars:,.0f}")
print('Number of counts =', f"{bdata.X.sum():,.0f}")
print('Mean counts per cell =', f"{bdata.X.sum()/adata.n_obs:,.0f}")
adata
# Out:
# Data matrix is sparse: True
#
# Index(['AAACAGCCAACATAAG_sc85_3g_sc85_3g', 'AAACAGCCAATGAAGC_sc85_3g_sc85_3g'], dtype='object')
#
# Number of cells = 11,794
# Number of genes = 25,525
# Number of counts = 13,816,905
# Mean counts per cell = 1,018
# AnnData object with n_obs × n_vars = 13572 × 25525
#     obs: 'scDblFinder_score', 'scDblFinder_class', 'doublet', 'n_genes_by_counts', 'total_counts'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'scDblFinder_class_colors', 'log1p', 'hvg', 'pca', 'neighbors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
n_cells = bdata.n_obs
n_genes = bdata.n_vars
n_counts = bdata.X.sum()    
counts_per_cell = round(n_counts / n_cells)

df_metrics = pd.DataFrame([n_cells, n_genes, n_counts, counts_per_cell], \
                  index = ['Number of cells', 'Number of genes', 'Number of counts','Mean counts per cell']).T
df_metrics.iloc[:, 1:] = df_metrics.iloc[:,1:].applymap('{:,.0f}'.format)
df_metrics.index = [sample_name]
df_metrics
# Out:
# C:\Users\leeh1\AppData\Local\Temp\ipykernel_12516\2166053342.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_metrics.iloc[:, 1:] = df_metrics.iloc[:,1:].applymap('{:,.0f}'.format)
# C:\Users\leeh1\AppData\Local\Temp\ipykernel_12516\2166053342.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0    25,525
# Name: Number of genes, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_metrics.iloc[:, 1:] = df_metrics.iloc[:,1:].applymap('{:,.0f}'.format)
# C:\Users\leeh1\AppData\Local\Temp\ipykernel_12516\2166053342.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0    13,816,905
# Name: Number of counts, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_metrics.iloc[:, 1:] = df_metrics.iloc[:,1:].applymap('{:,.0f}'.format)
# C:\Users\leeh1\AppData\Local\Temp\ipykernel_12516\2166053342.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0    1,172
# Name: Mean counts per cell, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_metrics.iloc[:, 1:] = df_metrics.iloc[:,1:].applymap('{:,.0f}'.format)
#          Number of cells Number of genes Number of counts Mean counts per cell
# sc85_3g          11794.0          25,525       13,816,905                1,172

# %%
sc.pp.filter_genes(bdata, min_cells=1)
df_metrics['Filter genes:'] = ' '
df_metrics['Number of genes removed'] = n_genes - bdata.n_vars
# Out:
# filtered out 396 genes that are detected in less than 1 cells

# %%
data_mat = bdata.X.T                 # transform data matrix
doublet_ratio = n_cells/1000*0.008   # calculate multiplet rate based on 10x formula
print('multiplet rate = %4.1f' %(doublet_ratio*100), '%')
# Out:
# multiplet rate =  9.4 %

# %%
# %%R -i data_mat -i doublet_ratio -o doublet_score -o doublet_class
#
# set.seed(123)
# sce = scDblFinder(SingleCellExperiment(list(counts=data_mat),), dbr=doublet_ratio)
# doublet_score = sce$scDblFinder.score
# doublet_class = sce$scDblFinder.class
# Out:
# Creating ~9436 artificial doublets...
# Dimensional reduction
# Evaluating kNN...
# Training model...
# iter=0, 1124 cells excluded from training.
# iter=1, 693 cells excluded from training.
# iter=2, 647 cells excluded from training.
# Threshold found:0.394
# 461 (3.9%) doublets called

# %%
doublets = [1.0 if x == 'doublet' else 0 for x in doublet_class]
bdata.obs["scDblFinder_score"] = doublet_score
bdata.obs["scDblFinder_class"] = doublet_class
bdata.obs["doublet"] = doublets

# %%
doublet_percentage = sum(doublets)/bdata.n_obs*100
print('Doublet percentage = %4.1f' %(doublet_percentage))
df_metrics['Doublet removal:'] = ' '
df_metrics['Doublet percentage'] =  doublet_percentage

bdata.obs.scDblFinder_class.value_counts()
# Out:
# Doublet percentage =  3.9
# scDblFinder_class
# singlet    11333
# doublet      461
# Name: count, dtype: int64

# %%
num_before = bdata.n_obs
singlets = bdata.obs["scDblFinder_class"] == 'singlet'
num_after = bdata[singlets].n_obs
n_genes = bdata[singlets].n_vars
n_counts = bdata[singlets].X.sum()    
counts_per_cell = round(n_counts / n_cells)

print('Number of cells before doublet removal =', num_before)
print('Number of cells after doublet removal =', num_after)
print('Number of cells removed =', num_before - num_after)
removed_percentage = (num_before - num_after)/num_before*100
print('Percentage of cells removed = %4.1f' %(removed_percentage))
n_counts = bdata.X.sum()  
print('Number of counts =', f"{n_counts:,.0f}")
print('Mean counts per cell =', f"{counts_per_cell:,.0f}")

df_metrics['Number of cells removed'] =  num_before - num_after
df_metrics['After doublet removal:'] = ' '
df_metrics['Number of cells -db'] = num_after
df_metrics['Number of genes -db'] = n_genes
df_metrics['Number of counts -db'] = n_counts
df_metrics['Mean counts per cell -db'] = counts_per_cell
# Out:
# Number of cells before doublet removal = 11794
# Number of cells after doublet removal = 11333
# Number of cells removed = 461
# Percentage of cells removed =  3.9
# Number of counts = 13,816,905
# Mean counts per cell = 1,102

# %% [markdown]
# ### UMAP
# Visualize the data before and after doublet removal.

# %%
sc.pp.normalize_total(bdata)
sc.pp.log1p(bdata)
sc.pp.highly_variable_genes(bdata)
sc.tl.pca(bdata)
sc.pp.neighbors(bdata)
sc.tl.umap(bdata)
# Out:
# normalizing counts per cell
#     finished (0:00:00)
# extracting highly variable genes
#     finished (0:00:00)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)
# computing PCA
#     with n_comps=50
#     finished (0:00:01)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:04)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm)
#     'umap', UMAP parameters (adata.uns) (0:00:11)

# %%
rcParams['figure.figsize'] = 6, 5.5
sc.pl.umap(bdata, color=['doublet'])

# %% [markdown]
# ### Exporting New Doublets

# %%
bdata_dbl = bdata.obs["scDblFinder_class"] == 'doublet'
bdata_dbl = bdata.obs_names[bdata_dbl]

# %%
with open("./results/scDblFinder_exp_sc85_3g_ids.txt", "w") as txt_file:
    for cell in bdata_dbl:
        txt_file.write(cell + "\n")
